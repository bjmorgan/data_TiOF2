# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cubic_data = pd.read_csv('TiOF2 fit PDF cubic model.csv', sep='\s+')
cubic_data
# Out:
#           r     calc      exp     diff
# 0      1.00 -0.57137 -0.64940 -0.07802
# 1      1.01 -0.64141 -0.66337 -0.02196
# 2      1.02 -0.70964 -0.68571  0.02393
# 3      1.03 -0.77503 -0.71607  0.05896
# 4      1.04 -0.83663 -0.75379  0.08284
# ...     ...      ...      ...      ...
# 3896  39.96 -0.12859 -0.16723 -0.03864
# 3897  39.97 -0.22525 -0.25917 -0.03392
# 3898  39.98 -0.32261 -0.35181 -0.02920
# 3899  39.99 -0.41991 -0.44455 -0.02464
# 3900  40.00 -0.51641 -0.53681 -0.02040
#
# [3901 rows x 4 columns]

# %%
plt.plot(cubic_data.r, cubic_data.exp)
plt.plot(cubic_data.r, cubic_data.calc)
plt.plot(cubic_data.r, cubic_data['diff'])
plt.show()

# %%
dft_data = pd.read_csv('TiOF2 fit PDF DFT model.csv', sep='\s+', na_values='--')
dft_data
# Out:
#           r     calc      exp     diff
# 0      1.00 -0.51038 -0.64940 -0.13901
# 1      1.01 -0.58215 -0.66337 -0.08122
# 2      1.02 -0.65501 -0.68571 -0.03070
# 3      1.03 -0.72779 -0.71607  0.01172
# 4      1.04 -0.79922 -0.75379  0.04543
# ...     ...      ...      ...      ...
# 3896  39.96      NaN -0.16723      NaN
# 3897  39.97      NaN -0.25917      NaN
# 3898  39.98      NaN -0.35181      NaN
# 3899  39.99      NaN -0.44455      NaN
# 3900  40.00      NaN -0.53681      NaN
#
# [3901 rows x 4 columns]

# %%
plt.plot(dft_data.r, dft_data.exp)
plt.plot(dft_data.r, dft_data.calc)
plt.plot(dft_data.r, dft_data['diff'])
plt.show()

# %%
# Out:
# <bound method DataFrame.diff of           r     calc      exp     diff
# 0      1.00 -0.51038 -0.64940 -0.13901
# 1      1.01 -0.58215 -0.66337 -0.08122
# 2      1.02 -0.65501 -0.68571 -0.03070
# 3      1.03 -0.72779 -0.71607  0.01172
# 4      1.04 -0.79922 -0.75379  0.04543
# ...     ...      ...      ...      ...
# 3896  39.96      NaN -0.16723      NaN
# 3897  39.97      NaN -0.25917      NaN
# 3898  39.98      NaN -0.35181      NaN
# 3899  39.99      NaN -0.44455      NaN
# 3900  40.00      NaN -0.53681      NaN
#
# [3901 rows x 4 columns]>
